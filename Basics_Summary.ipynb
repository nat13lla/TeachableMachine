# %% [markdown]
# <a href="https://colab.research.google.com/github/nat13lla/TeachableMachine/blob/main/Basics_Summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Dictionaries & Load data

# %% [markdown]
# Import the Dictionaries

# %%
# Pandas Data Library
import pandas as pd
# Maths Library
import numpy as np

# Visualisations libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Importing a Data Set

# %%
# Eg. csv upload
df1 = pd.read_csv("https://resources.digitalfutures.com/data-science/pokemon.csv")

# Eg. tsv upload
df2 = pd.read_csv('https://resources.digitalfutures.com/data-science/DatasaurusDozen.tsv',
                  encoding = 'ISO-8859-1', sep = '\t')
# (EDA 1)
dataset = "https://resources.digitalfutures.com/data-science/bestsellers.csv"
df3 = pd.read_csv(dataset)
# Create own
#df = pd.DataFrame({
#  'first_name': ['Sarah', 'John', 'Kyle', 'Joe'],
#  'last_name': ['Connor', 'Connor', 'Reese', 'Bonnot'],
#})

# %% [markdown]
# # EDA 0.0: Showing a column/describe the no. data/ group by

# %% [markdown]
# Looking at the data frame:

# %%
df2.head()
# Out:
#   dataset        x        y
# 0    dino  55.3846  97.1795
# 1    dino  51.5385  96.0256
# 2    dino  46.1538  94.4872
# 3    dino  42.8205  91.4103
# 4    dino  40.7692  88.3333

# %% [markdown]
# Look at specific columns in the data frame

# %%
df2[['x', 'y']].head()
# Out:
#          x        y
# 0  55.3846  97.1795
# 1  51.5385  96.0256
# 2  46.1538  94.4872
# 3  42.8205  91.4103
# 4  40.7692  88.3333

# %% [markdown]
# Gives the stats for the numerical columns of the data frame

# %%
df2.describe().head()
# Out:
#                  x            y
# count  1846.000000  1846.000000
# mean     54.265695    47.835099
# std      16.713001    26.847766
# min      15.560750     0.015119
# 25%      41.073403    22.561073

# %% [markdown]
# Can 'Group By' a given column

# %%
df2.groupby('dataset').describe()
# Out:
#                 x                                                         \
#             count       mean        std        min        25%        50%
# dataset
# away        142.0  54.266100  16.769825  15.560750  39.724115  53.340296
# bullseye    142.0  54.268730  16.769239  19.288205  41.627968  53.842088
# circle      142.0  54.267320  16.760013  21.863581  43.379116  54.023213
# dino        142.0  54.263273  16.765142  22.307700  44.102600  53.333300
# dots        142.0  54.260303  16.767735  25.443526  50.359707  50.976768
# h_lines     142.0  54.261442  16.765898  22.003709  42.293828  53.069678
# high_lines  142.0  54.268805  16.766704  17.893499  41.535981  54.168689
# slant_down  142.0  54.267849  16.766759  18.109472  42.890931  53.135159
# slant_up    142.0  54.265882  16.768853  20.209778  42.810866  54.261345
# star        142.0  54.267341  16.768959  27.024603  41.034210  56.534732
# v_lines     142.0  54.269927  16.769959  30.449654  49.964506  50.362890
# ...

# %% [markdown]
# Example of df2 plots sorted by the column data set

# %%
sns.relplot(x = 'x', y = 'y', col = 'dataset', kind = 'scatter', data = df2, col_wrap = 4)
plt.show()

# %% [markdown]
# # EDA 1.0

# %% [markdown]
# ## Head/Tail/Shape(column/row)/dtype/column_name

# %% [markdown]
# * First 5 terms

# %%
df3.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#   dumb_extra
# 0   awerewar
# 1   awerewar
# 2   awerewar
# 3   awerewar
# 4   awerewar

# %% [markdown]
# * Last 5 terms

# %%
df3.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre dumb_extra
# 545          4.9     9413      8  2019      Fiction   awerewar
# 546          4.7    14331      8  2016  Non Fiction   awerewar
# 547          4.7    14331      8  2017  Non Fiction   awerewar
# 548          4.7    14331      8  2018  Non Fiction   awerewar
# 549          4.7    14331      8  2019  Non Fiction   awerewar

# %% [markdown]
# * Look at the size

# %%
# (Rows, Columns)
df3.shape
# Out:
# (550, 8)

# %%
# No. of Rows
df3.shape[0]
# Out:
# 550

# %%
# No. of Columns
df3.shape[1]
# Out:
# 8

# %% [markdown]
# * Types of input in each columns

# %%
# Types of input in each columns
df3.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dumb_extra      object
# dtype: object

# %% [markdown]
# * Names of the columns

# %%
df3.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'dumb_extra'],
#       dtype='object')

# %% [markdown]
# ## Changing Column Type/Deleting Columns

# %% [markdown]
#  . is attribute notation
#
#  [] Key notation (just like dictionaries!!)

# %%
# Let's check the unique values in Genre!
df3["Genre"].unique()
# or
df3.Genre.unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# * Changing a column dtype

# %%
df3['Genre'] = df3['Genre'].astype('category')

# %%
# Now check the types
df3.dtypes
# Out:
# Name             object
# Author           object
# User Rating     float64
# Reviews           int64
# Price             int64
# Year              int64
# Genre          category
# dumb_extra       object
# dtype: object

# %% [markdown]
# * Example of dealing 'dumb_extra' column

# %%
# How many different terms are there
# Only holds one value for every row so irrelevant
df3.dumb_extra.unique()
# Out:
# array(['awerewar'], dtype=object)

# %%
# Drop the Unnecesary Column
# This just gives a preview
df3.drop(columns = ["dumb_extra"])
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# To make it actually happen assign it

drop_df = df3.drop(columns = ["dumb_extra"])

# %%
# Show that its done
df3.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#   dumb_extra
# 0   awerewar
# 1   awerewar
# 2   awerewar
# 3   awerewar
# 4   awerewar

# %% [markdown]
# Context:
# * Dropping works similarly to the '.sort()' method and the 'sorted()' function:
# * list.sort() -> actually sorting the list! -- using 'inplace = True'!
# * sorted(list) -> returning a copy of the list sorted!  -- if we want to preserve it, we need to asign it to a variable

# %%
# To stop Error message
try:
    df.drop(columns=['dumb_extra'], inplace = False)
except:
    print('Oops! Its already dropped!')
# Out:
# Oops! Its already dropped!

# %% [markdown]
# ## .Describe()

# %%
# By default only works on numerical columns
df3.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
# Can force it to look at all columns
df3.describe(include = 'all')
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#         User Rating       Reviews       Price         Year        Genre  \
# ...

# %% [markdown]
# ## Nulls

# %%
# Let's check for nulls!
    #True : Yes it is null!
    #False :  No it isnt null!
df3.isnull()
# Out:
#       Name  Author  User Rating  Reviews  Price   Year  Genre  dumb_extra
# 0    False   False        False    False  False  False  False       False
# 1    False   False        False    False  False  False  False       False
# 2    False   False        False    False  False  False  False       False
# 3    False   False        False    False  False  False  False       False
# 4    False   False        False    False  False  False  False       False
# ..     ...     ...          ...      ...    ...    ...    ...         ...
# 545  False   False        False    False  False  False  False       False
# 546  False   False        False    False  False  False  False       False
# 547  False   False        False    False  False  False  False       False
# 548  False   False        False    False  False  False  False       False
# 549  False   False        False    False  False  False  False       False
#
# [550 rows x 8 columns]

# %% [markdown]
# # EDA 2.0
